# %% [markdown]
# # Lecture 35
#
# ## Basic Data Manipulation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Workplace Fatalities by State Data
#
# Lets look at some workforce data... unfortunately the source site is no longer avaliable.

# %%
# !ls
# Out:
# 2012_Workplace_Fatalities_by_State.csv heart.csv
# Lecture.35.ipynb

# %%
# !head 2012_Workplace_Fatalities_by_State.csv
# Out:
# State,"Number of Fatalities, 2012","Rate of Fatalities, 2012","State Rank, Fatalities 2012",Number of Injuries/Illnesses 2012,Injuries/Illnesses 2012 Rate,Penalties FY 2013 (Average $),Penalties FY 2013 (Rank),Inspectors,Years to Inspect Each Workplace Once,State or Federal Program
# "South Carolina
# (33.99882060100049, -81.04536765699964)",63,3.5,25,36200,3,492,49,24,111,State
# "West Virginia
# (38.665511497000466, -80.71263935099967)",49,6.9,46,19800,4.1,1798,27,7,173,Federal
# "Massachusetts
# (42.27687306500047, -72.08268985899963)",44,1.4,1,69700,3.1,1929,21,33,123,Federal
# "Tennessee
# (35.680943063000484, -85.77448642199965)",101,3.8,30,65100,3.5,727,45,30,82,State
# "Oklahoma

# %%
df=pd.read_csv("2012_Workplace_Fatalities_by_State.csv")

# %%
df
# Out:
#                                                 State  \
# 0   South Carolina\n(33.99882060100049, -81.045367...
# 1   West Virginia\n(38.665511497000466, -80.712639...
# 2   Massachusetts\n(42.27687306500047, -72.0826898...
# 3   Tennessee\n(35.680943063000484, -85.7744864219...
# 4   Oklahoma\n(35.472034350000456, -97.52106845499...
# 5   Illinois\n(40.48501278700047, -88.99770813999965)
# 6   Nebraska\n(41.64104043900045, -99.36571864599966)
# 7   Delaware\n(39.00883351400046, -75.57773943699965)
# 8    Hawaii\n(21.30485166200043, -157.85774691599974)
# 9      Iowa\n(42.469404401000475, -93.81648936699969)
# 10  Arizona\n(34.865973091000455, -111.76380949799...
# 11  Florida\n(28.932042899000464, -81.92895558499964)
# 12  Virginia\n(37.54268075100049, -78.45788924199968)
# 13  Missouri\n(38.63579372300046, -92.56629737199967)
# 14  Michigan\n(44.66131575600048, -84.71438724399968)
# 15   Indiana\n(39.76691364600049, -86.14995579899966)
# 16  North Carolina\n(35.46622388600048, -79.159249...
# 17  New Hampshire\n(43.6559537330005, -71.50035726...
# 18  New Mexico\n(34.52088247800049, -106.240577688...
# 19  Pennsylvania\n(40.79373106100047, -77.86069775...
# 20  South Dakota\n(44.35313342000046, -100.3735281...
# 21  New York\n(42.82700023900048, -75.54396639699968)
# 22      Utah\n(39.36070374600047, -111.5871285339997)
# 23    Maine\n(45.254228663000504, -68.98502952999962)
# 24  Montana\n(47.066526051000494, -109.42441687999...
# 25   Vermont\n(43.62538292400046, -72.51763944499965)
# 26  Arkansas\n(34.748651751000466, -92.27448794899...
# 27   Nevada\n(39.49324126500045, -117.07183978499972)
# 28  Kentucky\n(37.645973909000475, -84.77496612599...
# 29   Maryland\n(39.2905806980005, -76.60925970899967)
# 30   Alabama\n(32.84057327200048, -86.63185803899967)
# 31  Connecticut\n(41.56266394200048, -72.649837536...
# 32  Oregon\n(44.567446178000466, -120.15502977999972)
# 33  Colorado\n(38.84384047000049, -106.13360888799...
# 34      Ohio\n(40.06021029700048, -82.40425685299965)
# 35  Wyoming\n(43.23554147100049, -108.10982744299969)
# 36  Minnesota\n(46.35564867700049, -94.79419697699...
# 37    Kansas\n(38.34774033400049, -98.20077655499966)
# 38    Idaho\n(43.682630058000484, -114.3637261449997)
# 39  Washington\n(47.522287905000496, -120.47002746...
# 40  Wisconsin\n(44.3931903350005, -89.81636715299965)
# 41  Mississippi\n(32.74551123200047, -89.538027644...
# 42  Louisiana\n(31.312662564000448, -92.4456755459...
# 43   Georgia\n(32.83968004200045, -83.62757601199968)
# 44  Rhode Island\n(41.70828281900049, -71.52246918...
# 45   Alaska\n(64.84507923900048, -147.72205669099972)
# 46  New Jersey\n(40.1305700530005, -74.27368565099...
# 47  North Dakota\n(47.47531738700047, -100.1184259...
# 48     Texas\n(31.827243635000457, -99.4267664729997)
# 49  California\n(37.638640488000476, -120.99999889...
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                         Total or National, Average
#
#     Number of Fatalities, 2012  Rate of Fatalities, 2012  \
# 0                         63.0                       3.5
# 1                         49.0                       6.9
# 2                         44.0                       1.4
# 3                        101.0                       3.8
# 4                         97.0                       6.1
# 5                        146.0                       2.5
# 6                         48.0                       5.2
# 7                         14.0                       3.1
# 8                         20.0                       3.4
# 9                         97.0                       6.6
# 10                        60.0                       2.3
# 11                       218.0                       2.7
# 12                       149.0                       3.8
# 13                        88.0                       3.3
# 14                       137.0                       3.4
# 15                       115.0                       4.2
# 16                       146.0                       3.5
# 17                        14.0                       2.2
# 18                        39.0                       4.8
# 19                       194.0                       3.4
# 20                        31.0                       6.7
# 21                       202.0                       2.4
# 22                        39.0                       3.0
# 23                        19.0                       3.2
# 24                        34.0                       7.3
# 25                        11.0                       3.5
# 26                        63.0                       5.4
# 27                        42.0                       3.6
# 28                        91.0                       4.9
# 29                        72.0                       2.6
# 30                        84.0                       4.3
# 31                        36.0                       2.1
# 32                        43.0                       2.6
# 33                        82.0                       3.5
# 34                       161.0                       3.1
# 35                        35.0                      12.2
# 36                        70.0                       2.6
# 37                        76.0                       5.7
# 38                        19.0                       2.7
# 39                        67.0                       2.2
# 40                       114.0                       4.0
# 41                        63.0                       5.5
# 42                       116.0                       6.4
# 43                       101.0                       2.5
# 44                         8.0                       1.7
# 45                        31.0                       8.9
# 46                        92.0                       2.4
# 47                        65.0                      17.7
# 48                       536.0                       4.8
# 49                       375.0                       2.3
# 50                         NaN                       NaN
# 51                         NaN                       NaN
# 52                         NaN                       NaN
# 53                      4628.0                       3.4
#
#     State Rank, Fatalities 2012  Number of Injuries/Illnesses 2012  \
# 0                          25.0                            36200.0
# 1                          46.0                            19800.0
# 2                           1.0                            69700.0
# 3                          30.0                            65100.0
# 4                          42.0                            39000.0
# 5                          10.0                           124900.0
# 6                          38.0                            24300.0
# 7                          18.0                             7900.0
# 8                          22.0                            13700.0
# 9                          44.0                            45600.0
# 10                          6.0                            54400.0
# 11                         15.0                                NaN
# 12                         30.0                            66200.0
# 13                         21.0                            60300.0
# 14                         22.0                           105500.0
# 15                         33.0                            77900.0
# 16                         25.0                            75900.0
# 17                          4.0                                NaN
# 18                         35.0                            19900.0
# 19                         22.0                           155300.0
# 20                         45.0                                NaN
# 21                          8.0                           146300.0
# 22                         17.0                            27700.0
# 23                         20.0                            21200.0
# 24                         47.0                            13300.0
# 25                         25.0                             9900.0
# 26                         39.0                            26600.0
# 27                         29.0                            32400.0
# 28                         37.0                            48900.0
# 29                         12.0                            51900.0
# 30                         34.0                            41200.0
# 31                          3.0                            43800.0
# 32                         12.0                            42900.0
# 33                         25.0                                NaN
# 34                         18.0                           113600.0
# 35                         49.0                             6500.0
# 36                         12.0                            67500.0
# 37                         41.0                            33400.0
# 38                         15.0                                NaN
# 39                          4.0                            89300.0
# 40                         32.0                            72900.0
# 41                         40.0                                NaN
# 42                         43.0                            30600.0
# 43                         10.0                            74800.0
# 44                          2.0                                NaN
# 45                         48.0                             9700.0
# 46                          8.0                            80900.0
# 47                         50.0                                NaN
# 48                         35.0                           203200.0
# 49                          6.0                           345400.0
# 50                          NaN                                NaN
# 51                          NaN                                NaN
# 52                          NaN                                NaN
# 53                          NaN                                NaN
#
#     Injuries/Illnesses 2012 Rate  Penalties FY 2013 (Average $)  \
# 0                            3.0                          492.0
# 1                            4.1                         1798.0
# 2                            3.1                         1929.0
# 3                            3.5                          727.0
# 4                            3.6                         1872.0
# 5                            3.2                         1876.0
# 6                            3.9                         2565.0
# 7                            2.8                         2406.0
# 8                            3.8                          964.0
# 9                            4.5                          790.0
# 10                           3.2                          891.0
# 11                           NaN                         1821.0
# 12                           2.7                          726.0
# 13                           3.3                         1931.0
# 14                           4.0                          542.0
# 15                           3.9                         1054.0
# 16                           2.9                          996.0
# 17                           NaN                         2243.0
# 18                           3.9                          998.0
# 19                           3.9                         1916.0
# 20                           NaN                         2346.0
# 21                           2.5                         2016.0
# 22                           3.4                         1053.0
# 23                           5.6                         2083.0
# 24                           5.0                         1983.0
# 25                           5.0                         1008.0
# 26                           3.2                         2569.0
# 27                           4.1                         2133.0
# 28                           4.1                         3254.0
# 29                           3.1                          685.0
# 30                           3.3                         1803.0
# 31                           3.9                         1735.0
# 32                           3.9                          363.0
# 33                           NaN                         1649.0
# 34                           3.2                         2156.0
# 35                           3.5                         1777.0
# 36                           3.8                          768.0
# 37                           3.6                         1971.0
# 38                           NaN                         1449.0
# 39                           4.8                          791.0
# 40                           4.0                         2207.0
# 41                           NaN                         1515.0
# 42                           2.3                         1765.0
# 43                           2.8                         2061.0
# 44                           NaN                         2023.0
# 45                           4.6                          889.0
# 46                           3.1                         2151.0
# 47                           NaN                         3045.0
# 48                           2.7                         2187.0
# 49                           3.5                         6422.0
# 50                           NaN                            NaN
# 51                           NaN                            NaN
# 52                           NaN                            NaN
# 53                           3.4                            NaN
#
#     Penalties FY 2013 (Rank)  Inspectors  \
# 0                       49.0        24.0
# 1                       27.0         7.0
# 2                       21.0        33.0
# 3                       45.0        30.0
# 4                       24.0        19.0
# 5                       23.0        74.0
# 6                        5.0         9.0
# 7                        6.0         5.0
# 8                       39.0        20.0
# 9                       43.0        26.0
# 10                      40.0        30.0
# 11                      25.0        60.0
# 12                      46.0        48.0
# 13                      20.0        26.0
# 14                      48.0        63.0
# 15                      34.0        39.0
# 16                      38.0       104.0
# 17                       8.0         7.0
# 18                      37.0         9.0
# 19                      22.0        57.0
# 20                       7.0         NaN
# 21                      17.0       105.0
# 22                      35.0        22.0
# 23                      14.0         8.0
# 24                      18.0         7.0
# 25                      36.0         9.0
# 26                       4.0         9.0
# 27                      13.0        44.0
# 28                       2.0        39.0
# 29                      47.0        48.0
# 30                      26.0        24.0
# 31                      30.0        24.0
# 32                      50.0        75.0
# 33                      31.0        28.0
# 34                      11.0        53.0
# 35                      28.0         9.0
# 36                      44.0        58.0
# 37                      19.0        16.0
# 38                      33.0         9.0
# 39                      42.0       111.0
# 40                       9.0        36.0
# 41                      32.0        14.0
# 42                      29.0        16.0
# 43                      15.0        49.0
# 44                      16.0         7.0
# 45                      41.0        11.0
# 46                      12.0        67.0
# 47                       3.0         8.0
# 48                      10.0        98.0
# 49                       1.0       216.0
# 50                       NaN         NaN
# 51                       NaN         NaN
# 52                       NaN         NaN
# 53                       NaN         NaN
#
#     Years to Inspect Each Workplace Once State or Federal Program
# 0                                  111.0                    State
# 1                                  173.0                  Federal
# 2                                  123.0                  Federal
# 3                                   82.0                    State
# 4                                  131.0                  Federal
# 5                                  137.0                  Federal
# 6                                  128.0                  Federal
# 7                                  175.0                  Federal
# 8                                   79.0                    State
# 9                                   98.0                    State
# 10                                 126.0                    State
# 11                                 238.0                  Federal
# 12                                  82.0                    State
# 13                                 118.0                  Federal
# 14                                  45.0                    State
# 15                                 104.0                    State
# 16                                  60.0                    State
# 17                                 119.0                  Federal
# 18                                 191.0                    State
# 19                                 125.0                  Federal
# 20                                 521.0                  Federal
# 21                                 184.0                  Federal
# 22                                  81.0                    State
# 23                                  80.0                  Federal
# 24                                 135.0                  Federal
# 25                                  68.0                    State
# 26                                 237.0                  Federal
# 27                                  49.0                    State
# 28                                 124.0                    State
# 29                                 108.0                    State
# 30                                  94.0                  Federal
# 31                                 107.0                  Federal
# 32                                  31.0                    State
# 33                                 122.0                  Federal
# 34                                 112.0                  Federal
# 35                                 101.0                    State
# 36                                  57.0                    State
# 37                                 110.0                  Federal
# 38                                 108.0                  Federal
# 39                                  50.0                    State
# 40                                 104.0                  Federal
# 41                                 112.0                  Federal
# 42                                 206.0                  Federal
# 43                                 138.0                  Federal
# 44                                 103.0                  Federal
# 45                                  58.0                    State
# 46                                 123.0                  Federal
# 47                                 111.0                  Federal
# 48                                 136.0                  Federal
# 49                                 179.0                    State
# 50                                   NaN                      NaN
# 51                                   NaN                      NaN
# 52                                   NaN                      NaN
# 53                                   NaN                      NaN

# %%
df.columns[1]
# Out:
# 'Number of Fatalities, 2012'

# %%
# To access a column
df[df.columns[1]][:50]
# Out:
# 0      63.0
# 1      49.0
# 2      44.0
# 3     101.0
# 4      97.0
# 5     146.0
# 6      48.0
# 7      14.0
# 8      20.0
# 9      97.0
# 10     60.0
# 11    218.0
# 12    149.0
# 13     88.0
# 14    137.0
# 15    115.0
# 16    146.0
# 17     14.0
# 18     39.0
# 19    194.0
# 20     31.0
# 21    202.0
# 22     39.0
# 23     19.0
# 24     34.0
# 25     11.0
# 26     63.0
# 27     42.0
# 28     91.0
# 29     72.0
# 30     84.0
# 31     36.0
# 32     43.0
# 33     82.0
# 34    161.0
# 35     35.0
# 36     70.0
# 37     76.0
# 38     19.0
# 39     67.0
# 40    114.0
# 41     63.0
# 42    116.0
# 43    101.0
# 44      8.0
# 45     31.0
# 46     92.0
# 47     65.0
# 48    536.0
# 49    375.0
# Name: Number of Fatalities, 2012, dtype: float64

# %% [markdown]
# Lets find the state with the max number of fatalities:

# %%
# Max of a column
# Note that the last 4 rows are not states
np.max(df[df.columns[1]][0:50])
# Out:
# 536.0

# %%
# What was the index of the max?
np.argmax(df[df.columns[1]][0:50])
# Out:
# 48

# %%
# What was the state?
df[df.columns[0]][np.argmax(df[df.columns[1]][0:50])]
# Out:
# 'Texas\n(31.827243635000457, -99.4267664729997)'

# %% [markdown]
# The state names aren't quite right... lets look:

# %%
# State names:
df[df.columns[0]][0:50]
# Out:
# 0     South Carolina\n(33.99882060100049, -81.045367...
# 1     West Virginia\n(38.665511497000466, -80.712639...
# 2     Massachusetts\n(42.27687306500047, -72.0826898...
# 3     Tennessee\n(35.680943063000484, -85.7744864219...
# 4     Oklahoma\n(35.472034350000456, -97.52106845499...
# 5     Illinois\n(40.48501278700047, -88.99770813999965)
# 6     Nebraska\n(41.64104043900045, -99.36571864599966)
# 7     Delaware\n(39.00883351400046, -75.57773943699965)
# 8      Hawaii\n(21.30485166200043, -157.85774691599974)
# 9        Iowa\n(42.469404401000475, -93.81648936699969)
# 10    Arizona\n(34.865973091000455, -111.76380949799...
# 11    Florida\n(28.932042899000464, -81.92895558499964)
# 12    Virginia\n(37.54268075100049, -78.45788924199968)
# 13    Missouri\n(38.63579372300046, -92.56629737199967)
# 14    Michigan\n(44.66131575600048, -84.71438724399968)
# 15     Indiana\n(39.76691364600049, -86.14995579899966)
# 16    North Carolina\n(35.46622388600048, -79.159249...
# 17    New Hampshire\n(43.6559537330005, -71.50035726...
# 18    New Mexico\n(34.52088247800049, -106.240577688...
# 19    Pennsylvania\n(40.79373106100047, -77.86069775...
# 20    South Dakota\n(44.35313342000046, -100.3735281...
# 21    New York\n(42.82700023900048, -75.54396639699968)
# 22        Utah\n(39.36070374600047, -111.5871285339997)
# 23      Maine\n(45.254228663000504, -68.98502952999962)
# 24    Montana\n(47.066526051000494, -109.42441687999...
# 25     Vermont\n(43.62538292400046, -72.51763944499965)
# 26    Arkansas\n(34.748651751000466, -92.27448794899...
# 27     Nevada\n(39.49324126500045, -117.07183978499972)
# 28    Kentucky\n(37.645973909000475, -84.77496612599...
# 29     Maryland\n(39.2905806980005, -76.60925970899967)
# 30     Alabama\n(32.84057327200048, -86.63185803899967)
# 31    Connecticut\n(41.56266394200048, -72.649837536...
# 32    Oregon\n(44.567446178000466, -120.15502977999972)
# 33    Colorado\n(38.84384047000049, -106.13360888799...
# 34        Ohio\n(40.06021029700048, -82.40425685299965)
# 35    Wyoming\n(43.23554147100049, -108.10982744299969)
# 36    Minnesota\n(46.35564867700049, -94.79419697699...
# 37      Kansas\n(38.34774033400049, -98.20077655499966)
# 38      Idaho\n(43.682630058000484, -114.3637261449997)
# 39    Washington\n(47.522287905000496, -120.47002746...
# 40    Wisconsin\n(44.3931903350005, -89.81636715299965)
# 41    Mississippi\n(32.74551123200047, -89.538027644...
# 42    Louisiana\n(31.312662564000448, -92.4456755459...
# 43     Georgia\n(32.83968004200045, -83.62757601199968)
# 44    Rhode Island\n(41.70828281900049, -71.52246918...
# 45     Alaska\n(64.84507923900048, -147.72205669099972)
# 46    New Jersey\n(40.1305700530005, -74.27368565099...
# 47    North Dakota\n(47.47531738700047, -100.1184259...
# 48       Texas\n(31.827243635000457, -99.4267664729997)
# 49    California\n(37.638640488000476, -120.99999889...
# Name: State, dtype: object

# %%
# Clean it up
state_names=list(map(lambda x: x.split("\n")[0],df[df.columns[0]][0:50]))
state_names
# Out:
# ['South Carolina',
#  'West Virginia',
#  'Massachusetts',
#  'Tennessee',
#  'Oklahoma',
#  'Illinois',
#  'Nebraska',
#  'Delaware',
#  'Hawaii',
#  'Iowa',
#  'Arizona',
#  'Florida',
#  'Virginia',
#  'Missouri',
#  'Michigan',
#  'Indiana',
#  'North Carolina',
#  'New Hampshire',
#  'New Mexico',
#  'Pennsylvania',
#  'South Dakota',
#  'New York',
#  'Utah',
#  'Maine',
#  'Montana',
#  'Vermont',
#  'Arkansas',
#  'Nevada',
#  'Kentucky',
#  'Maryland',
#  'Alabama',
#  'Connecticut',
#  'Oregon',
#  'Colorado',
#  'Ohio',
#  'Wyoming',
#  'Minnesota',
#  'Kansas',
#  'Idaho',
#  'Washington',
#  'Wisconsin',
#  'Mississippi',
#  'Louisiana',
#  'Georgia',
#  'Rhode Island',
#  'Alaska',
#  'New Jersey',
#  'North Dakota',
#  'Texas',
#  'California']

# %%
longitude=list(map(lambda x: float(x.split("\n")[1].split(",")[0][1:]),df[df.columns[0]][0:50]))
latitude=list(map(lambda x: float(x.split("\n")[1].split(",")[1][:-1]),df[df.columns[0]][0:50]))

coordinates=list(zip(longitude,latitude))
coordinates
# Out:
# [(33.99882060100049, -81.04536765699964),
#  (38.665511497000466, -80.71263935099967),
#  (42.27687306500047, -72.08268985899963),
#  (35.680943063000484, -85.77448642199965),
#  (35.472034350000456, -97.52106845499969),
#  (40.48501278700047, -88.99770813999965),
#  (41.64104043900045, -99.36571864599966),
#  (39.00883351400046, -75.57773943699965),
#  (21.30485166200043, -157.85774691599974),
#  (42.469404401000475, -93.81648936699969),
#  (34.865973091000455, -111.76380949799972),
#  (28.932042899000464, -81.92895558499964),
#  (37.54268075100049, -78.45788924199968),
#  (38.63579372300046, -92.56629737199967),
#  (44.66131575600048, -84.71438724399968),
#  (39.76691364600049, -86.14995579899966),
#  (35.46622388600048, -79.15924924699965),
#  (43.6559537330005, -71.50035726399966),
#  (34.52088247800049, -106.24057768899968),
#  (40.79373106100047, -77.86069775999965),
#  (44.35313342000046, -100.37352811899967),
#  (42.82700023900048, -75.54396639699968),
#  (39.36070374600047, -111.5871285339997),
#  (45.254228663000504, -68.98502952999962),
#  (47.066526051000494, -109.42441687999968),
#  (43.62538292400046, -72.51763944499965),
#  (34.748651751000466, -92.27448794899965),
#  (39.49324126500045, -117.07183978499972),
#  (37.645973909000475, -84.77496612599964),
#  (39.2905806980005, -76.60925970899967),
#  (32.84057327200048, -86.63185803899967),
#  (41.56266394200048, -72.64983753699966),
#  (44.567446178000466, -120.15502977999972),
#  (38.84384047000049, -106.13360888799969),
#  (40.06021029700048, -82.40425685299965),
#  (43.23554147100049, -108.10982744299969),
#  (46.35564867700049, -94.79419697699967),
#  (38.34774033400049, -98.20077655499966),
#  (43.682630058000484, -114.3637261449997),
#  (47.522287905000496, -120.47002746299972),
#  (44.3931903350005, -89.81636715299965),
#  (32.74551123200047, -89.53802764499966),
#  (31.312662564000448, -92.44567554599968),
#  (32.83968004200045, -83.62757601199968),
#  (41.70828281900049, -71.52246918099962),
#  (64.84507923900048, -147.72205669099972),
#  (40.1305700530005, -74.27368565099965),
#  (47.47531738700047, -100.11842599699969),
#  (31.827243635000457, -99.4267664729997),
#  (37.638640488000476, -120.99999889499969)]

# %%
df.shape
# Out:
# (54, 11)

# %%
df["State"]= state_names+[""]*3+["Total"]
df["Longitude"]=longitude+[0.]*4
df["Latitude"]=latitude+[0.]*4

# %%
df
# Out:
#              State  Number of Fatalities, 2012  Rate of Fatalities, 2012  \
# 0   South Carolina                        63.0                       3.5
# 1    West Virginia                        49.0                       6.9
# 2    Massachusetts                        44.0                       1.4
# 3        Tennessee                       101.0                       3.8
# 4         Oklahoma                        97.0                       6.1
# 5         Illinois                       146.0                       2.5
# 6         Nebraska                        48.0                       5.2
# 7         Delaware                        14.0                       3.1
# 8           Hawaii                        20.0                       3.4
# 9             Iowa                        97.0                       6.6
# 10         Arizona                        60.0                       2.3
# 11         Florida                       218.0                       2.7
# 12        Virginia                       149.0                       3.8
# 13        Missouri                        88.0                       3.3
# 14        Michigan                       137.0                       3.4
# 15         Indiana                       115.0                       4.2
# 16  North Carolina                       146.0                       3.5
# 17   New Hampshire                        14.0                       2.2
# 18      New Mexico                        39.0                       4.8
# 19    Pennsylvania                       194.0                       3.4
# 20    South Dakota                        31.0                       6.7
# 21        New York                       202.0                       2.4
# 22            Utah                        39.0                       3.0
# 23           Maine                        19.0                       3.2
# 24         Montana                        34.0                       7.3
# 25         Vermont                        11.0                       3.5
# 26        Arkansas                        63.0                       5.4
# 27          Nevada                        42.0                       3.6
# 28        Kentucky                        91.0                       4.9
# 29        Maryland                        72.0                       2.6
# 30         Alabama                        84.0                       4.3
# 31     Connecticut                        36.0                       2.1
# 32          Oregon                        43.0                       2.6
# 33        Colorado                        82.0                       3.5
# 34            Ohio                       161.0                       3.1
# 35         Wyoming                        35.0                      12.2
# 36       Minnesota                        70.0                       2.6
# 37          Kansas                        76.0                       5.7
# 38           Idaho                        19.0                       2.7
# 39      Washington                        67.0                       2.2
# 40       Wisconsin                       114.0                       4.0
# 41     Mississippi                        63.0                       5.5
# 42       Louisiana                       116.0                       6.4
# 43         Georgia                       101.0                       2.5
# 44    Rhode Island                         8.0                       1.7
# 45          Alaska                        31.0                       8.9
# 46      New Jersey                        92.0                       2.4
# 47    North Dakota                        65.0                      17.7
# 48           Texas                       536.0                       4.8
# 49      California                       375.0                       2.3
# 50                                         NaN                       NaN
# 51                                         NaN                       NaN
# 52                                         NaN                       NaN
# 53                                      4628.0                       3.4
#
#     State Rank, Fatalities 2012  Number of Injuries/Illnesses 2012  \
# 0                          25.0                            36200.0
# 1                          46.0                            19800.0
# 2                           1.0                            69700.0
# 3                          30.0                            65100.0
# 4                          42.0                            39000.0
# 5                          10.0                           124900.0
# 6                          38.0                            24300.0
# 7                          18.0                             7900.0
# 8                          22.0                            13700.0
# 9                          44.0                            45600.0
# 10                          6.0                            54400.0
# 11                         15.0                                NaN
# 12                         30.0                            66200.0
# 13                         21.0                            60300.0
# 14                         22.0                           105500.0
# 15                         33.0                            77900.0
# 16                         25.0                            75900.0
# 17                          4.0                                NaN
# 18                         35.0                            19900.0
# 19                         22.0                           155300.0
# 20                         45.0                                NaN
# 21                          8.0                           146300.0
# 22                         17.0                            27700.0
# 23                         20.0                            21200.0
# 24                         47.0                            13300.0
# 25                         25.0                             9900.0
# 26                         39.0                            26600.0
# 27                         29.0                            32400.0
# 28                         37.0                            48900.0
# 29                         12.0                            51900.0
# 30                         34.0                            41200.0
# 31                          3.0                            43800.0
# 32                         12.0                            42900.0
# 33                         25.0                                NaN
# 34                         18.0                           113600.0
# 35                         49.0                             6500.0
# 36                         12.0                            67500.0
# 37                         41.0                            33400.0
# 38                         15.0                                NaN
# 39                          4.0                            89300.0
# 40                         32.0                            72900.0
# 41                         40.0                                NaN
# 42                         43.0                            30600.0
# 43                         10.0                            74800.0
# 44                          2.0                                NaN
# 45                         48.0                             9700.0
# 46                          8.0                            80900.0
# 47                         50.0                                NaN
# 48                         35.0                           203200.0
# 49                          6.0                           345400.0
# 50                          NaN                                NaN
# 51                          NaN                                NaN
# 52                          NaN                                NaN
# 53                          NaN                                NaN
#
#     Injuries/Illnesses 2012 Rate  Penalties FY 2013 (Average $)  \
# 0                            3.0                          492.0
# 1                            4.1                         1798.0
# 2                            3.1                         1929.0
# 3                            3.5                          727.0
# 4                            3.6                         1872.0
# 5                            3.2                         1876.0
# 6                            3.9                         2565.0
# 7                            2.8                         2406.0
# 8                            3.8                          964.0
# 9                            4.5                          790.0
# 10                           3.2                          891.0
# 11                           NaN                         1821.0
# 12                           2.7                          726.0
# 13                           3.3                         1931.0
# 14                           4.0                          542.0
# 15                           3.9                         1054.0
# 16                           2.9                          996.0
# 17                           NaN                         2243.0
# 18                           3.9                          998.0
# 19                           3.9                         1916.0
# 20                           NaN                         2346.0
# 21                           2.5                         2016.0
# 22                           3.4                         1053.0
# 23                           5.6                         2083.0
# 24                           5.0                         1983.0
# 25                           5.0                         1008.0
# 26                           3.2                         2569.0
# 27                           4.1                         2133.0
# 28                           4.1                         3254.0
# 29                           3.1                          685.0
# 30                           3.3                         1803.0
# 31                           3.9                         1735.0
# 32                           3.9                          363.0
# 33                           NaN                         1649.0
# 34                           3.2                         2156.0
# 35                           3.5                         1777.0
# 36                           3.8                          768.0
# 37                           3.6                         1971.0
# 38                           NaN                         1449.0
# 39                           4.8                          791.0
# 40                           4.0                         2207.0
# 41                           NaN                         1515.0
# 42                           2.3                         1765.0
# 43                           2.8                         2061.0
# 44                           NaN                         2023.0
# 45                           4.6                          889.0
# 46                           3.1                         2151.0
# 47                           NaN                         3045.0
# 48                           2.7                         2187.0
# 49                           3.5                         6422.0
# 50                           NaN                            NaN
# 51                           NaN                            NaN
# 52                           NaN                            NaN
# 53                           3.4                            NaN
#
#     Penalties FY 2013 (Rank)  Inspectors  \
# 0                       49.0        24.0
# 1                       27.0         7.0
# 2                       21.0        33.0
# 3                       45.0        30.0
# 4                       24.0        19.0
# 5                       23.0        74.0
# 6                        5.0         9.0
# 7                        6.0         5.0
# 8                       39.0        20.0
# 9                       43.0        26.0
# 10                      40.0        30.0
# 11                      25.0        60.0
# 12                      46.0        48.0
# 13                      20.0        26.0
# 14                      48.0        63.0
# 15                      34.0        39.0
# 16                      38.0       104.0
# 17                       8.0         7.0
# 18                      37.0         9.0
# 19                      22.0        57.0
# 20                       7.0         NaN
# 21                      17.0       105.0
# 22                      35.0        22.0
# 23                      14.0         8.0
# 24                      18.0         7.0
# 25                      36.0         9.0
# 26                       4.0         9.0
# 27                      13.0        44.0
# 28                       2.0        39.0
# 29                      47.0        48.0
# 30                      26.0        24.0
# 31                      30.0        24.0
# 32                      50.0        75.0
# 33                      31.0        28.0
# 34                      11.0        53.0
# 35                      28.0         9.0
# 36                      44.0        58.0
# 37                      19.0        16.0
# 38                      33.0         9.0
# 39                      42.0       111.0
# 40                       9.0        36.0
# 41                      32.0        14.0
# 42                      29.0        16.0
# 43                      15.0        49.0
# 44                      16.0         7.0
# 45                      41.0        11.0
# 46                      12.0        67.0
# 47                       3.0         8.0
# 48                      10.0        98.0
# 49                       1.0       216.0
# 50                       NaN         NaN
# 51                       NaN         NaN
# 52                       NaN         NaN
# 53                       NaN         NaN
#
#     Years to Inspect Each Workplace Once State or Federal Program  \
# 0                                  111.0                    State
# 1                                  173.0                  Federal
# 2                                  123.0                  Federal
# 3                                   82.0                    State
# 4                                  131.0                  Federal
# 5                                  137.0                  Federal
# 6                                  128.0                  Federal
# 7                                  175.0                  Federal
# 8                                   79.0                    State
# 9                                   98.0                    State
# 10                                 126.0                    State
# 11                                 238.0                  Federal
# 12                                  82.0                    State
# 13                                 118.0                  Federal
# 14                                  45.0                    State
# 15                                 104.0                    State
# 16                                  60.0                    State
# 17                                 119.0                  Federal
# 18                                 191.0                    State
# 19                                 125.0                  Federal
# 20                                 521.0                  Federal
# 21                                 184.0                  Federal
# 22                                  81.0                    State
# 23                                  80.0                  Federal
# 24                                 135.0                  Federal
# 25                                  68.0                    State
# 26                                 237.0                  Federal
# 27                                  49.0                    State
# 28                                 124.0                    State
# 29                                 108.0                    State
# 30                                  94.0                  Federal
# 31                                 107.0                  Federal
# 32                                  31.0                    State
# 33                                 122.0                  Federal
# 34                                 112.0                  Federal
# 35                                 101.0                    State
# 36                                  57.0                    State
# 37                                 110.0                  Federal
# 38                                 108.0                  Federal
# 39                                  50.0                    State
# 40                                 104.0                  Federal
# 41                                 112.0                  Federal
# 42                                 206.0                  Federal
# 43                                 138.0                  Federal
# 44                                 103.0                  Federal
# 45                                  58.0                    State
# 46                                 123.0                  Federal
# 47                                 111.0                  Federal
# 48                                 136.0                  Federal
# 49                                 179.0                    State
# 50                                   NaN                      NaN
# 51                                   NaN                      NaN
# 52                                   NaN                      NaN
# 53                                   NaN                      NaN
#
#         State Name  Longitude    Latitude
# 0   South Carolina  33.998821  -81.045368
# 1    West Virginia  38.665511  -80.712639
# 2    Massachusetts  42.276873  -72.082690
# 3        Tennessee  35.680943  -85.774486
# 4         Oklahoma  35.472034  -97.521068
# 5         Illinois  40.485013  -88.997708
# 6         Nebraska  41.641040  -99.365719
# 7         Delaware  39.008834  -75.577739
# 8           Hawaii  21.304852 -157.857747
# 9             Iowa  42.469404  -93.816489
# 10         Arizona  34.865973 -111.763809
# 11         Florida  28.932043  -81.928956
# 12        Virginia  37.542681  -78.457889
# 13        Missouri  38.635794  -92.566297
# 14        Michigan  44.661316  -84.714387
# 15         Indiana  39.766914  -86.149956
# 16  North Carolina  35.466224  -79.159249
# 17   New Hampshire  43.655954  -71.500357
# 18      New Mexico  34.520882 -106.240578
# 19    Pennsylvania  40.793731  -77.860698
# 20    South Dakota  44.353133 -100.373528
# 21        New York  42.827000  -75.543966
# 22            Utah  39.360704 -111.587129
# 23           Maine  45.254229  -68.985030
# 24         Montana  47.066526 -109.424417
# 25         Vermont  43.625383  -72.517639
# 26        Arkansas  34.748652  -92.274488
# 27          Nevada  39.493241 -117.071840
# 28        Kentucky  37.645974  -84.774966
# 29        Maryland  39.290581  -76.609260
# 30         Alabama  32.840573  -86.631858
# 31     Connecticut  41.562664  -72.649838
# 32          Oregon  44.567446 -120.155030
# 33        Colorado  38.843840 -106.133609
# 34            Ohio  40.060210  -82.404257
# 35         Wyoming  43.235541 -108.109827
# 36       Minnesota  46.355649  -94.794197
# 37          Kansas  38.347740  -98.200777
# 38           Idaho  43.682630 -114.363726
# 39      Washington  47.522288 -120.470027
# 40       Wisconsin  44.393190  -89.816367
# 41     Mississippi  32.745511  -89.538028
# 42       Louisiana  31.312663  -92.445676
# 43         Georgia  32.839680  -83.627576
# 44    Rhode Island  41.708283  -71.522469
# 45          Alaska  64.845079 -147.722057
# 46      New Jersey  40.130570  -74.273686
# 47    North Dakota  47.475317 -100.118426
# 48           Texas  31.827244  -99.426766
# 49      California  37.638640 -120.999999
# 50                   0.000000    0.000000
# 51                   0.000000    0.000000
# 52                   0.000000    0.000000
# 53                   0.000000    0.000000

# %%
fig,ax= plt.subplots(1,1,figsize=(10,10))

ax.bar(range(50),df[df.columns[1]][0:50])
ax.set_xticks(range(50))
_=ax.set_xticklabels(state_names, rotation='vertical', fontsize=10)
_=ax.set_ylabel(df.columns[1])

# %%
fig,ax= plt.subplots(1,1,figsize=(10,10))

ax.bar(range(50),df[df.columns[2]][0:50])
ax.set_xticks(range(50))
_=ax.set_xticklabels(state_names, rotation='vertical', fontsize=10)
_=ax.set_ylabel(df.columns[2])

# %%
fig,ax= plt.subplots(1,1,figsize=(10,10))

ax.bar(range(50),df[df.columns[9]][0:50])
ax.set_xticks(range(50))
_=ax.set_xticklabels(state_names, rotation='vertical', fontsize=10)
_=ax.set_ylabel(df.columns[9])

# %%
plt.scatter(df[df.columns[2]][0:50],df[df.columns[9]][0:50])

# %%
fig,ax= plt.subplots(1,1,figsize=(10,10))

ax.bar(range(50),df[df.columns[2]][0:50]/df[df.columns[9]][0:50])
ax.set_xticks(range(50))
_=ax.set_xticklabels(state_names, rotation='vertical', fontsize=10)
_=ax.set_ylabel(df.columns[2]+"/"+df.columns[9])

# %% [markdown]
# ### Heart Data
#
# [Source](https://www.kaggle.com/ronitf/heart-disease-uci/version/1#)
#
# * *age*- age in years
# * *sex*- (1 = male; 0 = female)
# * *cp*- chest pain type
# * *trestbps*- resting blood pressure (in mm Hg on admission to the hospital)
# * *chol*- serum cholestoral in mg/dl
# * *fbs*- (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# * *restecg*- resting electrocardiographic results
# * *thalach*- maximum heart rate achieved
# * *exang*- exercise induced angina (1 = yes; 0 = no)
# * *oldpeak*- ST depression induced by exercise relative to rest
# * *slope*- the slope of the peak exercise ST segment
# * *ca*- number of major vessels (0-3) colored by flourosopy
# * *thal*- 3 = normal; 6 = fixed defect; 7 = reversable defect
# * *target*- 1 or 0

# %%
# !head heart.csv
# Out:
# ﻿age,sex,cp,trestbps,chol,fbs,restecg,thalach,exang,oldpeak,slope,ca,thal,target
# 63,1,3,145,233,1,0,150,0,2.3,0,0,1,1
# 37,1,2,130,250,0,1,187,0,3.5,0,0,2,1
# 41,0,1,130,204,0,0,172,0,1.4,2,0,2,1
# 56,1,1,120,236,0,1,178,0,0.8,2,0,2,1
# 57,0,0,120,354,0,1,163,1,0.6,2,0,2,1
# 57,1,0,140,192,0,1,148,0,0.4,1,0,1,1
# 56,0,1,140,294,0,0,153,0,1.3,1,0,2,1
# 44,1,1,120,263,0,1,173,0,0,2,0,3,1
# 52,1,2,172,199,1,1,162,0,0.5,2,0,3,1

# %%
df_heart=pd.read_csv("heart.csv")

# %%
df_heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
np_heart=np.array(df_heart)
np_heart.shape
# Out:
# (303, 14)

# %%
h_c_tmp=df_heart.columns.tolist()
h_columns=dict(zip(h_c_tmp,range(len(h_c_tmp))))
h_columns
# Out:
# {'age': 0,
#  'sex': 1,
#  'cp': 2,
#  'trestbps': 3,
#  'chol': 4,
#  'fbs': 5,
#  'restecg': 6,
#  'thalach': 7,
#  'exang': 8,
#  'oldpeak': 9,
#  'slope': 10,
#  'ca': 11,
#  'thal': 12,
#  'target': 13}

# %%
h_c_tmp
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %%
index=np.where(np_heart[:,h_columns["cp"]]==0.)

# %%
len(index[0])
# Out:
# 143

# %%
_=plt.hist(np_heart[index,h_columns["chol"]].flatten(),bins=50)

# %%
index=np.where(np_heart[:,h_columns["cp"]]==0)
_=plt.hist(np_heart[index,h_columns["chol"]].flatten(),color="r",bins=50,density=1.)
index=np.where(np_heart[:,h_columns["cp"]]!=0)
_=plt.hist(np_heart[index,h_columns["chol"]].flatten(),color="b",bins=50,density=1.)

# %%
index=np.where(np_heart[:,h_columns["cp"]]==0)
print (np.mean(np_heart[index,h_columns["chol"]].flatten()))
index=np.where(np_heart[:,h_columns["cp"]]!=0)
print (np.mean(np_heart[index,h_columns["chol"]].flatten()))
# Out:
# 250.13286713286712
# 242.80625

# %%
dict(zip(h_c_tmp,np.corrcoef(np.array(np_heart).transpose())[h_columns["cp"]]))
# Out:
# {'age': -0.06865301584014483,
#  'sex': -0.049352875346989386,
#  'cp': 1.0,
#  'trestbps': 0.04760776064464842,
#  'chol': -0.07690439103320763,
#  'fbs': 0.09444403499533158,
#  'restecg': 0.04442059251016377,
#  'thalach': 0.2957621245879105,
#  'exang': -0.39428026849502146,
#  'oldpeak': -0.14923015809708068,
#  'slope': 0.11971658853470613,
#  'ca': -0.18105302605349535,
#  'thal': -0.1617355705100218,
#  'target': 0.4337982615068934}
