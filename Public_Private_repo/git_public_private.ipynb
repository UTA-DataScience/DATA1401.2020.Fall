# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/UTA-DataScience/DATA1401.2020.Fall/blob/master/Public_Private_repo/git_public_private.ipynb)
#
# ## 1.Create a private repository in Github with the name "DATA1401.2020.Fall_lastname"
# ![Screen Shot 2020-10-28 at 12.47.32 PM.png](data:image/png;base64,...)

# %% [markdown]
# Add the collaborators https://github.com/afarbin , https://github.com/meghamodi by going in the settings and Manage access and invite a collaborator to your private repo

# %% [markdown]
# #2.Duplicate the repo as follows:-

# %% [markdown]
# ### clone your existing repository(your existing codes/Labs) using the below command

# %%
# change the respository name to your repo name
# !git clone --bare https://github.com/username/existing_repo.git

# %% [markdown]
# ### cd into your existing repository using the following command

# %%
cd existing_repo/

# %% [markdown]
# ### Check if you are in the right directory using the command

# %%
# !pwd

# %% [markdown]
# ### Provide your Github credentials username and password in the below cell

# %%
username = 'abc'; password = '####';

# %% [markdown]
# ### Set the name for your new repo
#
# Make sure you change "lastname" to *your* last name.

# %%
new_repo_name="DATA1401.2020.Fall_lastname.git"

# %% [markdown]
# ### Now push the existing repo into your new private repo

# %%
# !git push --mirror https://$username:$password@github.com/$username/$new_repo_name

# %% [markdown]
# ### Move out of the directory using the command

# %%
cd ..

# %% [markdown]
# ### Now that you have pushed all the changes, remove the existing repository

# %%
rm -rf existing_repo/

# %% [markdown]
# #3.Clone the private repo so you can work on it:

# %%
# !git clone https://$username:$password@github.com/$username/$new_repo_name

# %%
cd new_repo_name

# %% [markdown]
# (optional)If you want to add any files(add a file, etc).You might have to give your credential: use
#
# !git config --global user.email "xxx@gmail.com"
#
# !git config --global user.name "abxmm"
#
# - git add filename
# - git commit -m “ ”

# %%
# !git push origin master

# %% [markdown]
# #4.To pull changes from the public repo:

# %%
# !git remote add public https://github.com/UTA-DataScience/DATA1401.2020.Fall.git

# %% [markdown]
# ### Add your email and username for Github config

# %%
# !git config --global user.email "xxx@gmail.com"
# !git config --global user.name "abxmm"

# %%
# !git commit -m "changes"

# %% [markdown]
# ### Pull the changes from the repository(DATA1401.2020.Fall) using the command

# %%
# !git pull public master

# %% [markdown]
# ### Push the changes to your private repo using the below command

# %%
# !git push origin master

# %% [markdown]
# ### Using the command to check the status

# %%
# !git status
